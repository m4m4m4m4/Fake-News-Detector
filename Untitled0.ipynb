# %% [markdown]
# <a href="https://colab.research.google.com/github/m4m4m4m4/Fake-News-Detector/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import necessary libraries and install packages
import pandas as pd
import re
import sklearn

# !pip install transformers
import transformers

import tokenizers
import torch
# !pip install git+https://github.com/PytorchLightning/pytorch-lightning.git@master --upgrade
import pytorch_lightning as pl
# Out:
# ...
#      |████████████████████████████████| 3.4 MB 5.4 MB/s
# ...
#      |████████████████████████████████| 895 kB 29.8 MB/s
# ...
#      |████████████████████████████████| 61 kB 283 kB/s
# ...
#      |████████████████████████████████| 596 kB 14.6 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 35.3 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...
#   Cloning https://github.com/PytorchLightning/pytorch-lightning.git (to revision master) to /tmp/pip-req-build-dbmb0yfj
#   Running command git clone -q https://github.com/PytorchLightning/pytorch-lightning.git /tmp/pip-req-build-dbmb0yfj
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 332 kB 5.4 MB/s
# ...

# %%
# import and mount drive to access data
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# set root location to folder containing data for processing
root_path = 'gdrive/My Drive/FakeNewsDetectFiles/'  #set the root directory to the folder containing the data

# %%
# read data using pandas
real_news = pd.read_csv("gdrive/My Drive/FakeNewsDetectFiles/Khilnani_LP_real_news.csv")
fake_news = pd.read_csv("gdrive/My Drive/FakeNewsDetectFiles/Khilnani_LP_fake_news.csv")

# assign data labels
real_news["label"] = 0
fake_news["label"] = 1

# %%
# preview data in the csv files
real_news.head()
#fake_news.head()

# Note: These datasets appear to be politically biased and I do not personally
#       agree with their views. I am only concerned with building the NLP
#       pipeline and verifying that it can differentiate between the 2 files
# Out:
#                                                title  ... label
# 0  As U.S. budget fight looms, Republicans flip t...  ...     0
# 1  U.S. military to accept transgender recruits o...  ...     0
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...  ...     0
# 3  FBI Russia probe helped by Australian diplomat...  ...     0
# 4  Trump wants Postal Service to charge 'much mor...  ...     0
#
# [5 rows x 5 columns]

# %%
# Concatenate the two dataframes row-wise and randomly shuffle the resulting 
# dataframe
data = pd.concat([real_news, fake_news])
data = data.sample(frac=1)

# %%
# We only need the 'Text' and 'Label' columns
data = data[["text", "label"]]

#preview to make sure we extracted only these 2 columns
data.head()
# Out:
#                                                     text  label
# 14807  (Reuters) - U.S. airline Alaska Airlines on Tu...      0
# 19556  Why a recount only in states that Trump won?Wh...      1
# 13276  TEGUCIGALPA (Reuters) - Honduran security forc...      0
# 12229  MOSCOW (Reuters) - Russia is open to working w...      0
# 16830  KABUL (Reuters) - Suicide bombers attacked two...      0

# %%
# Clean the data by converting each article to lowercase letters and removing 
# stopwords, symbols, and numbers

# install NLTK to do this
import nltk
nltk.download("stopwords")

# function for removing unwanted characters
def clean_text(input_str):
    
    stopwords = nltk.corpus.stopwords.words('english')
    input_str = input_str.lower()
    
    ## Remove numbers and symbols from the text as well
    words = [word for word in input_str.split() if word not in stopwords]
    input_str = " ".join(words)
    
    ## Return output
    return input_str
    
    '''
    ## Removes everything except words from a given string
    input_str = re.sub(r'[^\w\s]', '', input_str)

    ## Change text to lowercase
    input_str = input_str.lower()

    ## Return output
    return input_str
    '''

# apply cleaning function to data
data["text"] = data["text"].apply(clean_text)

# preview data to verify it is properly cleaned
data.head()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                                     text  label
# 14807  (reuters) - u.s. airline alaska airlines tuesd...      0
# 19556  recount states trump won?why recount michigan,...      1
# 13276  tegucigalpa (reuters) - honduran security forc...      0
# 12229  moscow (reuters) - russia open working united ...      0
# 16830  kabul (reuters) - suicide bombers attacked two...      0

# %%
# Split data into training and validation sets


# Split the data into train and validation sets

#train_data, val_data, train_labels, val_labels = train_test_split(data["text"].tolist(), data["label"].tolist())


## method 1 of using train_test_split
from sklearn.model_selection import train_test_split

train, test = train_test_split(data, test_size=0.2)


## another method of splitting train/test data
#train = data.sample(frac=0.8,random_state=200) #random state is a seed value
#test = data.drop(train.index)

# preview train dataframe
train.head()
# Out:
#                                                     text  label
# 12606  must watch: msnbc interviews black women voter...      1
# 20980  easy target, almost like could 4 year mini-ser...      1
# 19076  brussels (reuters) - british eu negotiators ta...      0
# 6710   (reuters) - following people mentioned contend...      0
# 594    washington (reuters) - wife republican u.s. se...      0

# %%
# imports for creating a custom tokenizer

from tokenizers import Tokenizer
from tokenizers.models import BPE
from tokenizers.trainers import BpeTrainer
from tokenizers.pre_tokenizers import Whitespace

# Write training and test data to one file to process
data = train + test
data.to_csv(r'gdrive/My Drive/FakeNewsDetectFiles/data.txt', header=None, index=None, sep=' ', mode='a')

tokenizer = Tokenizer(BPE(unk_token="[UNK]"))
tokenizer.pre_tokenizer = Whitespace()

trainer = BpeTrainer(special_tokens=["[UNK]", "[CLS]", "[SEP]", "[PAD]", "[MASK]"])

files = ["gdrive/My Drive/FakeNewsDetectFiles/data.txt"]
tokenizer.train(files, trainer)

# %%
# Add PAD special token to this tokenizer using add_special_tokens() method
from transformers import PreTrainedTokenizerFast
trained_tokenizer = PreTrainedTokenizerFast(tokenizer_object=tokenizer)
